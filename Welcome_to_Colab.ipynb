# %% [markdown]
# <a href="https://colab.research.google.com/github/jane-nyambura2/adding-numbers/blob/master/Welcome_to_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
#loading dataset feature i.e weight & height
x=[[170,65],[185,85],[160,55],[178,75]]
#loading labels.i.e yes,no
y={" NO","YES","NO","YES"}
new_point={180,78}#new feature added
print(x)
print(y)
# Out:
# hello world
# [[170, 65], [185, 85], [160, 55], [178, 75]]
# {' NO', 'NO', 'YES'}

# %%
def Knn ( X,Y,new-point,K=3 ):
 distances=[]#it will store the distance
  #loop though all known datapoints for i in range(len(X)):
d=distances(X[i],new_point)#calculate distance to the new point distance.append(('d,y[i]))
  #store distance together with it's lables distance.sort()#sort the list by distance(smallest first)
neighbors= distances [:K] #take the first K classest points
votes={}#dictionary to count how many times each label appears
  #go through each neighbor
for_,label in neighbors:
if label not in votes:#if label not seen before
   votes[label]=0#start counting form 0
#return max(votes,key=votes.get)#returns the label with the highest votes
# Out:
#   File "/tmp/ipykernel_18648/895281055.py", line 1
#     def Knn ( X,Y,new-point,K=3 ):
#                      ^
# SyntaxError: invalid syntax
